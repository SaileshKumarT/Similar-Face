# %%
from clustimage import Clustimage
from PIL import Image
import cv2

cl = Clustimage(method='pca')

face_results = cl.extract_faces('1.jpg')

for i in range(2,1267,1):
    face_results1 = cl.extract_faces(f'{i}.jpg')
    face_results['pathnames_face'].append(face_results1['pathnames_face'][0])
    face_results['filenames'].append(f'{i}.jpg')
# Out:
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >INFO> filepath is set to [/tmp/clustimage]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 266.19it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 194.70it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 217.31it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 195.68it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 295.39it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 293.66it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 166.10it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 195.00it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 307.57it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 287.50it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 212.51it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 223.48it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 245.27it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 287.20it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 213.41it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 207.56it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 299.70it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 270.83it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 226.93it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 241.72it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 183.65it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 185.02it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 208.01it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 160.42it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 203.35it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 318.86it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 216.76it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 202.64it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 271.92it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 199.35it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 254.05it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 283.42it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 202.84it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 158.32it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 185.56it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 145.39it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 156.80it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 295.00it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 274.84it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 208.95it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 197.99it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 260.35it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 291.84it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 288.78it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 260.73it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 188.34it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 242.00it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 195.55it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 206.95it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 304.40it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 269.71it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 195.30it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 247.90it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 269.35it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 289.60it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 237.37it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 280.14it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 283.86it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 286.99it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 259.29it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 282.06it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 263.78it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 260.97it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 282.52it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 214.21it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 287.50it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 267.60it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 275.49it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 281.84it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 207.88it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 273.89it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 253.88it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 277.82it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 292.71it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 279.88it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 234.20it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 229.46it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 180.56it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 252.35it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 230.61it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 177.01it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 304.51it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 289.48it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 201.70it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 369.51it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 288.11it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 229.30it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 298.25it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 284.55it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 279.66it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 232.68it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 215.34it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 289.96it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 208.64it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 250.95it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 267.37it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 270.95it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 100.79it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 169.37it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 276.56it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 297.38it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 285.58it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 231.37it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 317.68it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 303.45it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 227.37it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 284.09it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 265.14it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 273.94it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 219.40it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 274.57it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 264.67it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 240.09it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 283.74it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 315.27it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 293.95it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 302.40it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 287.01it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 205.20it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 205.80it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 261.70it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 314.02it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 264.64it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 219.46it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 269.73it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 293.02it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 289.98it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 292.76it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 266.93it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 273.40it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 284.38it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 180.14it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 227.04it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 227.53it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 231.55it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 182.13it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 223.22it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 238.14it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 244.91it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 270.51it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 303.52it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 260.05it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 201.42it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 211.76it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 260.63it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 287.03it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 184.84it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 278.73it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 285.68it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 287.77it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 205.87it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 252.50it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 247.55it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 245.04it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 180.44it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 223.72it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 306.04it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 305.37it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 281.29it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 219.87it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 272.57it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 277.68it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 216.75it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 260.65it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 300.58it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 256.23it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 250.60it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 278.30it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 280.11it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 299.74it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 292.57it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 270.22it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 258.89it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 294.11it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 292.37it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 185.38it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 294.96it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 265.51it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 269.57it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 242.10it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 279.12it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 293.02it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 372.13it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 291.68it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 292.33it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 293.16it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 191.55it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 280.20it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 286.44it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 240.06it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 287.30it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 275.47it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 301.38it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 312.52it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 301.57it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 293.37it/s]
# ...
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 265.61it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 293.68it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 241.84it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 276.29it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 250.33it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 281.12it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 303.61it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 266.75it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 265.08it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 301.51it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 288.25it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 217.78it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 224.97it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 267.89it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 283.82it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 277.47it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 288.65it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 288.11it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 211.09it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 169.90it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 272.27it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 289.50it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 252.27it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 261.62it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 133.28it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 236.06it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 219.09it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 294.32it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 257.95it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 283.36it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 267.14it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 253.83it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 267.32it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 295.79it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 278.97it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 248.85it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 240.54it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 279.53it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 316.48it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 222.73it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 232.69it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 247.36it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 274.53it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 275.52it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 271.41it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 260.81it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 207.38it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 271.65it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 287.66it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 250.78it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 288.55it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 210.90it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 239.59it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 253.34it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 233.26it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 263.21it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 225.59it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 277.40it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 226.18it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 298.04it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 254.26it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 270.69it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 286.87it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 272.38it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 186.16it/s]
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 259.73it/s]

# %%
results = cl.fit_transform(face_results['pathnames_face'])
# Out:
# [clustimage] >INFO> Cleaning previous fitted model results
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 282/282 [00:00<00:00, 1767.26it/s]
# [clustimage] >INFO> Extracting features using method: [pca]
# [pca] >Column labels are auto-completed.
# [pca] >The PCA reduction is performed to capture [95.0%] explained variance using the [49152] columns of the input data.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [pca] >Compute explained variance.
# [pca] >Number of components is [180] that covers the [95.00%] explained variance.
# [pca] >The PCA reduction is performed on the [49152] columns of the input dataframe.
# [pca] >Fit using PCA.
# [pca] >Compute loadings and PCs.
# [clustimage] >INFO> Extracted features using [pca]: samples=282, features=180
# [clustimage] >INFO> Compute [tsne] embedding
# [clustimage] >INFO> Cluster evaluation using the [high] feature space of the [pca] features.
# [clustimage] >INFO> Saving data in memory.
# [clustimage] >INFO> Fit with method=[agglomerative], metric=[euclidean], linkage=[ward]
# [clustimage] >INFO> Evaluate using silhouette.
# [clusteval] >INFO: 100%|██████████| 22/22 [00:00<00:00, 221.91it/s]
# [clustimage] >INFO> Compute dendrogram threshold.
# [clustimage] >INFO> Optimal number clusters detected: [3].
# [clustimage] >INFO> Fin.
# [clustimage] >INFO> Updating cluster-labels and cluster-model based on the (282, 180) feature-space.

# %%
path = './clustimage'
for j in range(len(face_results['pathnames_face'])):
    if face_results['pathnames_face'][j] != []:
        face_results['pathnames_face'][j] = path + face_results['pathnames_face'][j][0]
        
        

print(face_results['pathnames_face'])
# Out:
# ['./clustimage/tmp/clustimage/530c573e-e96b-493b-be6d-1a0b46de0516.png', './clustimage/tmp/clustimage/94248c42-f508-406e-8f42-70cd3013b65c.png', [], [], [], [], './clustimage/tmp/clustimage/29ccba24-7983-43cc-9930-6d8ff104b87c.png', [], './clustimage/tmp/clustimage/f1cd7329-8a4c-4342-b5c2-4a2c90407273.png', [], [], [], './clustimage/tmp/clustimage/d95e42d0-4b9a-4629-a515-abab813805e7.png', [], './clustimage/tmp/clustimage/3b5291c7-6f82-4e55-a385-d671f55b5a5e.png', [], [], [], './clustimage/tmp/clustimage/6569ead3-076a-42c0-aaf6-c0cabf2c5bf3.png', [], [], [], [], './clustimage/tmp/clustimage/edefd5c7-5472-49f9-a0c4-164b295b04fa.png', [], [], [], [], [], [], [], [], './clustimage/tmp/clustimage/37cb213a-19f4-4f5a-ab20-ec4ebfe5847b.png', [], [], [], [], [], [], [], './clustimage/tmp/clustimage/9a5f4e7b-f001-448a-ac67-f8e8ba3fc2e2.png', './clustimage/tmp/clustimage/e32cea2c-0454-48ed-bc1f-128016e1c7f3.png', [], [], [], [], [], [], [], [], [], [], [], [], './clustimage/tmp/clustimage/decc1e58-dcdd-41f1-a7ab-2848720355c0.png', [], './clustimage/tmp/clustimage/916c16e3-27d6-4589-8bd8-2cca6ac055a9.png', [], [], [], [], [], [], [], [], './clustimage/tmp/clustimage/f60c0454-39b7-4ee9-a24d-b82304ed4c40.png', [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [], [
# %%
cl.save('clustimage_model2', overwrite=True)
# Out:
# [clustimage] >INFO> Saving..
# [pypickle] Pickle file saved: [clustimage_model2.pkl]
# True

# %%
import cv2
img_add1 = './Test_image/test.jpg'
image = cv2.imread(img_add1,0)
cv2.imwrite('./Test_image/temp/test1.jpg',image)
# Out:
# True

# %%
face_results1= cl.extract_faces('./Test_image/temp/test1.jpg')
cl.plot_faces(faces=True, eyes=True)
# Out:
# [clustimage] >WARNING> It is advisable to set "grayscale=True" when detecting faces.
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 27.42it/s]

# %%
cl.load('clustimage_model')
results_find = cl.find(face_results1['pathnames_face'], k=1, alpha=0.05, metric = 'euclidean')
# Out:
# [pypickle] Pickle file loaded: [clustimage_model.pkl]
# [clustimage] >INFO> Load succesful!
# [clustimage] >INFO> Find similar images with metric [euclidean], k-nearest neighbors: 1 and under alpha: 0.05
# [clustimage] >INFO> Reading and checking images.
# [clustimage] >INFO> Reading and checking images.
# [clustimage]: 100%|██████████| 1/1 [00:00<00:00, 362.33it/s]
# [pca] >Column labels are auto-completed.
# [distfit] >INFO> fit
# [distfit] >INFO> transform
# [distfit] >INFO> [norm   ] [0.00 sec] [RSS: 7.31258e-09] [loc=18009.134 scale=3980.747]
# [distfit] >INFO> [expon  ] [0.00 sec] [RSS: 2.77526e-07] [loc=0.000 scale=18009.134]
# [distfit] >INFO> [uniform] [0.00 sec] [RSS: 2.34845e-07] [loc=0.000 scale=41506.667]
# [distfit] >INFO> [gamma  ] [0.93 sec] [RSS: 4.96985e-09] [loc=-36704.379 scale=287.633]
# [distfit] >INFO> [t      ] [0.82 sec] [RSS: 7.31192e-09] [loc=18009.129 scale=3980.679]
# [distfit] >INFO> Compute confidence intervals [parametric]
# [clustimage] >INFO> [1] similar images found for [ae770ce3-abdc-48f4-a88a-ce3f7f62042a.png]

# %%
cl.plot_find()
# Out:
# [clustimage] >WARNING> Could not read: [/tmp/clustimage/2d89a885-b5d7-4323-be2b-9f17b4b97aa1.png]

# %%
name = list(results_find[list(results_find.keys())[1]]['y_pathnames'])

# number = face_results['pathnames_face'].index(name)

number = face_results
print(name)
# Out:
# ['/tmp/clustimage/2d89a885-b5d7-4323-be2b-9f17b4b97aa1.png']

# %%
import pickle


with open('person_data1.pkl', 'wb') as fp:
    pickle.dump(face_results, fp)
    print('dictionary saved successfully to file')
# Out:
# dictionary saved successfully to file

# %%
img = './result/' + 'image' + str(face_results['filenames'][number])
img_A = Image.open(img)
img_add = './Test_image/test.jpg'
img_B = Image.open(img_add)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-37ffae4f8213> in <module>
# ----> 1 img = './result/' + 'image' + str(face_results['filenames'][number])
#       2 img_A = Image.open(img)
#       3 img_add = './Test_image/test.jpg'
#       4 img_B = Image.open(img_add)
#
# TypeError: list indices must be integers or slices, not dict

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import rcParams

# %matplotlib inline

# figure size in inches optional
rcParams['figure.figsize'] = 11 ,8

# display images
fig, ax = plt.subplots(1,2)
ax[0].imshow(img_B)
ax[1].imshow(img_A)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-7612396a7927> in <module>
#      10 # display images
#      11 fig, ax = plt.subplots(1,2)
# ---> 12 ax[0].imshow(img_B)
#      13 ax[1].imshow(img_A)
#
# NameError: name 'img_B' is not defined
